# %%
import sys
import os
sys.path.insert(0, os.path.abspath('/home/maldo/projects/virtualenvs/datathon/lib/python3.7/site-packages'))
sys.path.insert(0, os.path.abspath('/home/maldo/projects/datathon'))
from imblearn.under_sampling import *
from imblearn.over_sampling import *
from imblearn.combine import *
from src.models.model import SoilClassifier
from src.constants import *
from sklearn.base import clone
from src.features.features import ImbalanceTransformer
import pandas as pd
import seaborn as sns
import math

# %%
df = pd.read_csv(os.path.join('../data/processed', 'train_data.csv'))
df_test = pd.read_csv(os.path.join('../data/processed', 'test_data.csv'))
min_samples = 500
max_samples = 9000
features = ['not_correlated', 'cadastral_ordinal_encoder_onehot', 'log_area', 'log_antiquity', 'squared_geoms', 'pssr', 'savi']
classifier = 'gradient_boosting'

# %%
model = SoilClassifier(min_samples = min_samples,
                       max_samples = max_samples,
                       feature_names = features,
                       classifier = classifier)

# %%
model.fit(df, df[TARGET_FEATURE])

# %%
pipe = clone(model.pipeline)
clsf = pipe.steps.pop()
imb = pipe.steps.pop()

# %%
transformed_data = pipe.fit_transform(df)

# %%
transformed_data = pd.DataFrame(transformed_data, columns=pipe.named_steps['features'].get_feature_names())

# %%
import numpy as np
def correlation_features(data, features_names):
    """Compute feature correlation.

    :param data: the matrix to compute correlations
    :type data: Spacy Sparce Matrix
    :param features_names: the features names
    :type features_names: list
    :return: The features names
    :rtype: list
    """
    df = pd.DataFrame(data, columns=features_names)
    # Compute correlation matix
    corr_matrix = df.corr(method='pearson')
    # uppper triangular matrix
    upper_mask = np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool)
    upper = corr_matrix.where(upper_mask)
    # Get correlated features
    stack_non_null = upper.stack()
    list_corr_feats = [
        (idx0, idx1, v)
        for (idx0, idx1), v
        in zip(stack_non_null.index, stack_non_null.values)
    ]
    # Sorted according its correlation value.
    list_corr_feats = sorted(list_corr_feats,
                             key=lambda x: abs(x[2]),
                             reverse=True)
    return list_corr_feats

# %%
correlation_features(transformed_data, features_names=pipe.named_steps['features'].get_feature_names())
# Out:
# [('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -1.0),
#  ('not_correlated__GEOM_R1',
#   'squared_geoms__quad_GEOM_R1',
#   0.9784632281332182),
#  ('not_correlated__Q_G_3_1_0',
#   'not_correlated__Q_NIR_8_1_0',
#   0.9581120120216013),
#  ('pssr__PSSR', 'savi__SAVI', 0.9432135382126091),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__Q_G_3_0_5',
#   0.9383378375516469),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.9335670143224466),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__Q_G_3_1_0',
#   0.9276453688264251),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__Q_B_2_0_5',
#   0.9245407276648115),
#  ('not_correlated__Q_G_3_0_5',
#   'not_correlated__Q_B_2_0_5',
#   0.9128546345460538),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_G_3_0_1',
#   0.9080798370365291),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__Q_NIR_8_1_0',
#   0.8914209343702856),
#  ('not_correlated__Q_NIR_8_0_1',
#   'not_correlated__Q_NIR_8_0_5',
#   0.8840010122270282),
#  ('not_correlated__Q_B_2_0_1', 'savi__SAVI', -0.8809340676337789),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_G_3_0_5',
#   0.8250522051899941),
#  ('not_correlated__Q_B_2_0_1', 'pssr__PSSR', -0.8165387136062953),
#  ('not_correlated__Q_R_4_0_5', 'pssr__PSSR', -0.8103784910300748),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__Q_B_2_0_1',
#   0.8089004773230914),
#  ('not_correlated__Q_R_4_0_5', 'savi__SAVI', -0.8011950814519964),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_R_4_0_5',
#   0.7959819717804878),
#  ('not_correlated__Q_B_2_0_5', 'pssr__PSSR', -0.7949451055602714),
#  ('not_correlated__Q_G_3_0_1',
#   'not_correlated__Q_G_3_0_5',
#   0.7710459884654005),
#  ('not_correlated__Q_B_2_0_1',
#   'not_correlated__Q_B_2_0_5',
#   0.7594690177474315),
#  ('not_correlated__Q_B_2_0_5', 'savi__SAVI', -0.7580751443229693),
#  ('not_correlated__GEOM_R2',
#   'squared_geoms__quad_GEOM_R2',
#   0.7259114848680622),
#  ('not_correlated__GEOM_R3', 'log_area__log_AREA', -0.7237220161254906),
#  ('not_correlated__GEOM_R2', 'log_area__log_AREA', -0.718109409260343),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.7069611475916854),
#  ('not_correlated__GEOM_R2', 'not_correlated__GEOM_R3', 0.6927480081976009),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   0.6815674414631071),
#  ('not_correlated__Q_NIR_8_0_1', 'savi__SAVI', 0.6797576471251958),
#  ('not_correlated__Q_G_3_0_5',
#   'not_correlated__Q_B_2_0_1',
#   0.6735319024970837),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_B_2_0_5',
#   0.6604967086697661),
#  ('not_correlated__Q_NIR_8_0_5', 'savi__SAVI', 0.6544075825237651),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__Q_G_3_0_1',
#   0.6480243966128937),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_B_2_0_1',
#   0.6438214662826874),
#  ('not_correlated__Q_G_3_0_5', 'pssr__PSSR', -0.6393238590724282),
#  ('not_correlated__GEOM_R4',
#   'squared_geoms__quad_GEOM_R4',
#   0.6369532452038504),
#  ('squared_geoms__quad_GEOM_R3',
#   'squared_geoms__quad_GEOM_R4',
#   0.6368140315970093),
#  ('not_correlated__GEOM_R3',
#   'squared_geoms__quad_GEOM_R3',
#   0.6239850453894669),
#  ('not_correlated__Q_NIR_8_0_1', 'pssr__PSSR', 0.613303512190714),
#  ('not_correlated__Q_G_3_0_5', 'savi__SAVI', -0.5858425906805674),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   0.5670061332061805),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   0.5583236406001886),
#  ('not_correlated__Q_G_3_0_1', 'not_correlated__Q_B_2_0_5', 0.536767916933548),
#  ('not_correlated__Q_NIR_8_0_5', 'pssr__PSSR', 0.531802437179092),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   0.5283432750248049),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   0.5251918476301415),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   0.5151495351259499),
#  ('not_correlated__Q_B_2_0_1',
#   'not_correlated__Q_NIR_8_0_1',
#   -0.5002068331441623),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   0.49761406181072865),
#  ('not_correlated__Q_G_3_0_1',
#   'not_correlated__Q_NIR_8_0_1',
#   0.4959293267772927),
#  ('not_correlated__Q_R_4_0_1', 'pssr__PSSR', -0.4935205397147697),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   0.492922717631457),
#  ('not_correlated__Q_G_3_0_1',
#   'not_correlated__Q_NIR_8_0_5',
#   0.4900480042890683),
#  ('not_correlated__GEOM_R3',
#   'squared_geoms__quad_GEOM_R2',
#   0.48970312988463516),
#  ('not_correlated__Y', 'not_correlated__Q_G_3_0_1', -0.48827919031283257),
#  ('not_correlated__Y', 'not_correlated__Q_R_4_0_5', -0.4871226715619114),
#  ('not_correlated__Q_R_4_0_1', 'savi__SAVI', -0.48518865255764515),
#  ('not_correlated__Y', 'not_correlated__Q_R_4_0_1', -0.4792774011742581),
#  ('not_correlated__X', 'not_correlated__Q_B_2_0_5', 0.47910961861877044),
#  ('not_correlated__X', 'not_correlated__Q_G_3_0_5', 0.46776960654768385),
#  ('not_correlated__Y', 'not_correlated__Q_G_3_0_5', -0.45506058202869604),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.4499491314290756),
#  ('not_correlated__Q_B_2_0_1',
#   'not_correlated__Q_NIR_8_0_5',
#   -0.44899003148221667),
#  ('not_correlated__X', 'not_correlated__Q_R_4_0_5', 0.4329507901422828),
#  ('not_correlated__X', 'not_correlated__Q_R_4_0_1', 0.4317454342203216),
#  ('not_correlated__Y', 'pssr__PSSR', 0.4241093245634007),
#  ('squared_geoms__quad_GEOM_R2',
#   'squared_geoms__quad_GEOM_R3',
#   0.411165915513406),
#  ('not_correlated__Y', 'not_correlated__Q_B_2_0_5', -0.4042028384795708),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   0.39785806447056826),
#  ('not_correlated__Y', 'savi__SAVI', 0.39178360802873813),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.3895921180295299),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   0.3864529195036205),
#  ('not_correlated__Q_NIR_8_0_5',
#   'not_correlated__CONTRUCTIONYEAR',
#   0.37489039369444566),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.3712902313067035),
#  ('not_correlated__GEOM_R3', 'not_correlated__GEOM_R4', 0.36837644206870757),
#  ('not_correlated__Q_G_3_0_1', 'not_correlated__Q_B_2_0_1', 0.361071426545782),
#  ('not_correlated__Q_NIR_8_0_1',
#   'not_correlated__CONTRUCTIONYEAR',
#   0.36082993372713046),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__Q_B_2_1_0',
#   0.3581325367870429),
#  ('not_correlated__Q_G_3_1_0',
#   'not_correlated__Q_B_2_1_0',
#   0.3576762686019279),
#  ('not_correlated__Q_NIR_8_0_5',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.3527178371900889),
#  ('not_correlated__X', 'not_correlated__Q_B_2_0_1', 0.35130863480326324),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   0.35110915062606596),
#  ('not_correlated__GEOM_R2',
#   'squared_geoms__quad_GEOM_R3',
#   0.3504679599228022),
#  ('not_correlated__GEOM_R1', 'not_correlated__GEOM_R2', 0.34385946647857807),
#  ('not_correlated__Y', 'not_correlated__Q_B_2_0_1', -0.3418653671883591),
#  ('not_correlated__Q_NIR_8_0_1',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.33993320166595126),
#  ('not_correlated__GEOM_R2', 'squared_geoms__quad_GEOM_R1', 0.338776885521475),
#  ('not_correlated__X', 'pssr__PSSR', -0.33479962861292495),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   0.3326076509136023),
#  ('not_correlated__X', 'not_correlated__Q_G_3_0_1', 0.33174020990834796),
#  ('not_correlated__GEOM_R1', 'not_correlated__GEOM_R3', 0.32348831391829996),
#  ('not_correlated__CONTRUCTIONYEAR', 'savi__SAVI', 0.31780084177286266),
#  ('not_correlated__GEOM_R3',
#   'squared_geoms__quad_GEOM_R1',
#   0.3177220194806238),
#  ('not_correlated__X', 'savi__SAVI', -0.31323173256767656),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   0.3121691103194305),
#  ('not_correlated__Q_G_3_0_5',
#   'not_correlated__Q_B_2_1_0',
#   0.3070465789854527),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   0.29957387737768576),
#  ('not_correlated__Q_B_2_0_5', 'not_correlated__Q_B_2_1_0', 0.298926598340876),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__Q_B_2_1_0',
#   0.29854023515035727),
#  ('not_correlated__GEOM_R3',
#   'squared_geoms__quad_GEOM_R4',
#   0.2981650689197467),
#  ('not_correlated__Q_B_2_1_0',
#   'not_correlated__Q_NIR_8_1_0',
#   0.294737593063764),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   0.29322702438113374),
#  ('log_area__log_AREA', 'squared_geoms__quad_GEOM_R2', -0.2851176261927326),
#  ('not_correlated__GEOM_R4',
#   'squared_geoms__quad_GEOM_R3',
#   0.2805479635842819),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.2791052366973552),
#  ('log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   'savi__SAVI',
#   -0.2776788165557438),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   0.275210406241902),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   0.274950357933691),
#  ('not_correlated__Q_B_2_0_5',
#   'not_correlated__Q_NIR_8_0_1',
#   -0.26314839990365446),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   0.25634565261353165),
#  ('not_correlated__Y', 'not_correlated__Q_B_2_1_0', -0.2542105967062639),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   0.2503222146953913),
#  ('not_correlated__Q_G_3_0_1', 'pssr__PSSR', -0.24716712769020982),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   0.24677253165730667),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   0.2452852756797385),
#  ('not_correlated__Q_G_3_1_0', 'savi__SAVI', -0.24330478797479496),
#  ('not_correlated__Q_R_4_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.24303570063929256),
#  ('not_correlated__CONTRUCTIONYEAR', 'pssr__PSSR', 0.2422110765249745),
#  ('not_correlated__GEOM_R2', 'not_correlated__GEOM_R4', -0.24138252190666168),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__Q_G_3_1_0',
#   0.23301782945247979),
#  ('not_correlated__Q_G_3_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.23124339997394017),
#  ('not_correlated__Q_B_2_1_0', 'pssr__PSSR', -0.22749871314080267),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.22480497176027026),
#  ('not_correlated__Q_B_2_1_0', 'savi__SAVI', -0.22424292797968867),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_B_2_1_0',
#   0.22269133502049288),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.22133699820754407),
#  ('log_area__log_AREA', 'squared_geoms__quad_GEOM_R3', -0.2193245443161588),
#  ('not_correlated__Q_G_3_0_1',
#   'not_correlated__Q_B_2_1_0',
#   0.21792471146418918),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'pssr__PSSR',
#   0.21789799011834554),
#  ('not_correlated__Q_G_3_1_0', 'pssr__PSSR', -0.2162583309792899),
#  ('log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   'pssr__PSSR',
#   -0.2155981689577888),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_NIR_8_0_1',
#   0.21556304724993366),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   0.21020563277797155),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   0.20997297269290283),
#  ('not_correlated__Q_G_3_1_0',
#   'not_correlated__Q_B_2_0_5',
#   0.2079163449297749),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.20730011366144396),
#  ('not_correlated__Q_B_2_1_0',
#   'squared_geoms__quad_GEOM_R1',
#   0.20564517055263698),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   0.20417980113343467),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   0.19908104183009245),
#  ('not_correlated__Q_G_3_0_5',
#   'not_correlated__Q_NIR_8_0_5',
#   0.19907248711737566),
#  ('not_correlated__Q_R_4_1_0', 'savi__SAVI', -0.1987777765961058),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__Q_R_4_1_0',
#   0.19647562539652047),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__Q_NIR_8_0_1',
#   -0.19563791239111444),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'savi__SAVI',
#   0.19423402990237085),
#  ('not_correlated__Q_B_2_1_0', 'not_correlated__GEOM_R1', 0.18811754495257293),
#  ('not_correlated__Q_G_3_0_1', 'savi__SAVI', -0.18806887272931988),
#  ('not_correlated__Q_B_2_0_1',
#   'not_correlated__Q_B_2_1_0',
#   0.18373091495902846),
#  ('not_correlated__Q_R_4_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.1837010462714102),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.18016402018011127),
#  ('not_correlated__Q_B_2_0_1',
#   'not_correlated__CONTRUCTIONYEAR',
#   -0.17867300391006347),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__Q_B_2_0_5',
#   0.17732254988391952),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'pssr__PSSR',
#   0.1769703481684765),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_NIR_8_0_5',
#   0.17677263490300363),
#  ('not_correlated__GEOM_R1', 'log_area__log_AREA', -0.1749724839453241),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   0.17483546047233323),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   0.17471685058187925),
#  ('not_correlated__Q_NIR_8_1_0', 'savi__SAVI', -0.1718965341533954),
#  ('not_correlated__Q_G_3_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.17024101719182677),
#  ('not_correlated__Q_R_4_1_0', 'pssr__PSSR', -0.16800352353856815),
#  ('not_correlated__Q_G_3_0_5',
#   'not_correlated__Q_G_3_1_0',
#   0.16777808107465952),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.1673152969599306),
#  ('not_correlated__Q_G_3_1_0',
#   'not_correlated__Q_B_2_0_1',
#   0.16554840324053224),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.16341580106958994),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.16296009482395954),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.1627088828565721),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__Q_NIR_8_1_0',
#   0.16143271117171223),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   'pssr__PSSR',
#   0.15935754536410934),
#  ('not_correlated__Q_R_4_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.1576239041423782),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'savi__SAVI',
#   0.1573172534274123),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   'savi__SAVI',
#   0.15540187213769455),
#  ('log_area__log_AREA', 'squared_geoms__quad_GEOM_R1', -0.1546753840452071),
#  ('not_correlated__Y',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.1515070257787782),
#  ('not_correlated__Q_NIR_8_1_0', 'pssr__PSSR', -0.1486157706108509),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.14643442770583762),
#  ('not_correlated__Q_B_2_0_5',
#   'not_correlated__Q_NIR_8_1_0',
#   0.1460269053404548),
#  ('not_correlated__Q_B_2_0_1',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.14581605756805635),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   0.14568505648315272),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.1449431251450069),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   0.14468198367053983),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.14468198367053983),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   0.14453826174114637),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.14067437036458244),
#  ('not_correlated__Q_R_4_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.14027622264669268),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   0.1397103275422723),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'log_area__log_AREA',
#   0.1384195140688496),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   0.13694856810290254),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.13597742245174135),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'pssr__PSSR',
#   0.13570708294648126),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__Q_G_3_0_5',
#   0.13538367838510956),
#  ('not_correlated__Q_NIR_8_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   0.1351687168079421),
#  ('not_correlated__Q_G_3_1_0',
#   'not_correlated__CONTRUCTIONYEAR',
#   -0.13430232136752993),
#  ('not_correlated__Y', 'not_correlated__CONTRUCTIONYEAR', 0.1340408369875017),
#  ('not_correlated__Q_G_3_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.13382596135458616),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'log_area__log_AREA',
#   0.13211419858977788),
#  ('not_correlated__Q_G_3_0_1',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.12824720505573622),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   0.12635859573914773),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.12439436751031452),
#  ('not_correlated__Q_G_3_1_0',
#   'not_correlated__Q_NIR_8_0_1',
#   -0.12379896651995839),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__CONTRUCTIONYEAR',
#   -0.1235350861613353),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'log_area__log_AREA',
#   0.12330218224909989),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'savi__SAVI',
#   0.12250058225050904),
#  ('squared_geoms__quad_GEOM_R1',
#   'squared_geoms__quad_GEOM_R2',
#   0.12080503391282368),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__CONTRUCTIONYEAR',
#   -0.12061190176216918),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.11999462950335822),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   0.11918788301964266),
#  ('not_correlated__Q_G_3_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.1191345625533749),
#  ('not_correlated__Y', 'not_correlated__Q_R_4_1_0', -0.11818150408706724),
#  ('not_correlated__X', 'not_correlated__Q_G_3_1_0', 0.1173905536816346),
#  ('not_correlated__Q_G_3_0_1',
#   'not_correlated__CONTRUCTIONYEAR',
#   0.11525980129175216),
#  ('not_correlated__Q_NIR_8_1_0',
#   'not_correlated__CONTRUCTIONYEAR',
#   -0.11521988610327501),
#  ('not_correlated__GEOM_R1',
#   'squared_geoms__quad_GEOM_R2',
#   0.11510914628560824),
#  ('not_correlated__Q_B_2_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.1143415654562693),
#  ('not_correlated__Q_G_3_1_0',
#   'not_correlated__Q_NIR_8_0_5',
#   -0.1117829940128489),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.11163310890400951),
#  ('not_correlated__X', 'not_correlated__Q_R_4_1_0', 0.11043374440761843),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__Q_B_2_0_1',
#   0.11002884705931966),
#  ('not_correlated__Q_B_2_0_5',
#   'not_correlated__Q_NIR_8_0_5',
#   -0.10817529476598854),
#  ('not_correlated__Q_G_3_1_0',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.10737113887729378),
#  ('not_correlated__X',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.106956616524254),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_G_3_1_0',
#   0.10581594242547589),
#  ('not_correlated__Q_B_2_0_1',
#   'not_correlated__Q_NIR_8_1_0',
#   0.10565320721966802),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   0.10518312963598014),
#  ('not_correlated__Q_B_2_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.10403795077867894),
#  ('not_correlated__GEOM_R2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.1033711008488273),
#  ('not_correlated__Q_G_3_0_5',
#   'not_correlated__Q_NIR_8_1_0',
#   0.10316999433925224),
#  ('not_correlated__Q_R_4_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   -0.10308099269320524),
#  ('not_correlated__GEOM_R3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   -0.10242436923595302),
#  ('not_correlated__Q_NIR_8_0_1', 'log_area__log_AREA', -0.10237358019089715),
#  ('not_correlated__X', 'not_correlated__Q_NIR_8_1_0', 0.10231086737526174),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.10218293539146643),
#  ('not_correlated__GEOM_R1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   0.10114477925113072),
#  ('not_correlated__Q_G_3_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   -0.10077373600584802),
#  ('not_correlated__Q_R_4_1_0',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.1001194155360723),
#  ('not_correlated__Q_R_4_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.09907528340917987),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   0.09906552585440465),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'log_area__log_AREA',
#   0.09776832595393618),
#  ('not_correlated__Q_NIR_8_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   0.09771734029522743),
#  ('not_correlated__Q_NIR_8_0_1',
#   'not_correlated__Q_NIR_8_1_0',
#   -0.09716650749178649),
#  ('not_correlated__GEOM_R1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   0.09587387422186548),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'log_area__log_AREA',
#   0.09506681604006663),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   -0.09369920277927415),
#  ('log_area__log_AREA', 'savi__SAVI', -0.09221534086282214),
#  ('not_correlated__Q_G_3_1_0', 'not_correlated__GEOM_R1', 0.09128555173195108),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   -0.09107432067922029),
#  ('not_correlated__Y', 'not_correlated__Q_G_3_1_0', -0.09104862339310363),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.09104550613553566),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__Q_NIR_8_0_1',
#   -0.09101048514746994),
#  ('not_correlated__Q_NIR_8_1_0',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.09092459621806703),
#  ('not_correlated__Q_G_3_1_0',
#   'squared_geoms__quad_GEOM_R1',
#   0.09063338659734937),
#  ('not_correlated__GEOM_R3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.09015764100719068),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'squared_geoms__quad_GEOM_R1',
#   0.09012773772493199),
#  ('not_correlated__Q_G_3_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.08929895865108317),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.08887188883071542),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   -0.0883482188600697),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   -0.08830155824977141),
#  ('not_correlated__Q_R_4_0_5',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.08746845010374793),
#  ('not_correlated__GEOM_R4',
#   'squared_geoms__quad_GEOM_R2',
#   -0.0874129191826374),
#  ('not_correlated__Q_NIR_8_0_5', 'log_area__log_AREA', -0.08720967936006724),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'squared_geoms__quad_GEOM_R1',
#   0.0869705457086717),
#  ('not_correlated__X',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.08623680365079475),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   'log_area__log_AREA',
#   0.08621272431164302),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   0.08612190480495334),
#  ('not_correlated__Q_B_2_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.0860835300351494),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__Q_NIR_8_0_5',
#   -0.08579954687394435),
#  ('not_correlated__Y', 'not_correlated__Q_NIR_8_0_1', 0.08473478630528909),
#  ('not_correlated__Q_NIR_8_0_5',
#   'not_correlated__GEOM_R1',
#   -0.08469483241718533),
#  ('not_correlated__Q_B_2_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.08335454887724915),
#  ('not_correlated__Q_B_2_0_5', 'log_area__log_AREA', 0.08322693330094405),
#  ('not_correlated__Q_G_3_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.08252677078266484),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__Q_NIR_8_0_5',
#   -0.08233532422354296),
#  ('not_correlated__Q_R_4_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.08126136500121664),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   0.08123458048317106),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.08100266794887158),
#  ('not_correlated__Q_NIR_8_0_5',
#   'not_correlated__Q_NIR_8_1_0',
#   -0.0809269168402092),
#  ('not_correlated__GEOM_R1', 'pssr__PSSR', -0.07985135261496187),
#  ('not_correlated__GEOM_R2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.07936127635250241),
#  ('not_correlated__GEOM_R3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.07843027978523912),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'savi__SAVI',
#   0.07830591250247888),
#  ('squared_geoms__quad_GEOM_R1',
#   'squared_geoms__quad_GEOM_R3',
#   0.07626352770419605),
#  ('not_correlated__GEOM_R2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   -0.07568241773296891),
#  ('not_correlated__Q_NIR_8_1_0',
#   'squared_geoms__quad_GEOM_R1',
#   0.0756493476734306),
#  ('not_correlated__Q_NIR_8_1_0',
#   'not_correlated__GEOM_R1',
#   0.07458523743251193),
#  ('not_correlated__X', 'not_correlated__CONTRUCTIONYEAR', 0.07434411442428039),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'savi__SAVI',
#   0.07368314677096315),
#  ('not_correlated__Q_B_2_0_5',
#   'not_correlated__CONTRUCTIONYEAR',
#   -0.07346949702156678),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   0.07192427151190396),
#  ('not_correlated__Q_NIR_8_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   0.07172607431327485),
#  ('not_correlated__Q_NIR_8_0_1',
#   'not_correlated__GEOM_R2',
#   0.0716369828951647),
#  ('not_correlated__Q_NIR_8_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   0.07135872666132319),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.0709303855178247),
#  ('not_correlated__Q_NIR_8_0_1',
#   'not_correlated__GEOM_R1',
#   -0.07067558414222708),
#  ('not_correlated__Q_NIR_8_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   0.07065755145409228),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   0.07054899119413974),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'log_area__log_AREA',
#   0.0699366539788515),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'pssr__PSSR',
#   0.06979841433034686),
#  ('not_correlated__GEOM_R2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.06917647948103255),
#  ('not_correlated__GEOM_R1',
#   'squared_geoms__quad_GEOM_R3',
#   0.06874366871104318),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.06826643649452831),
#  ('not_correlated__Q_NIR_8_0_1',
#   'not_correlated__GEOM_R3',
#   0.06815085442001582),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'pssr__PSSR',
#   0.06772606017067215),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.067546247202276),
#  ('squared_geoms__quad_GEOM_R1', 'pssr__PSSR', -0.06714715689623274),
#  ('not_correlated__GEOM_R2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.06703253198767826),
#  ('not_correlated__Q_NIR_8_0_5',
#   'not_correlated__GEOM_R2',
#   0.0669225101072439),
#  ('not_correlated__GEOM_R3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.06540537585483),
#  ('not_correlated__GEOM_R1', 'savi__SAVI', -0.06534483014714482),
#  ('not_correlated__GEOM_R2', 'savi__SAVI', 0.06485165754445998),
#  ('not_correlated__GEOM_R2',
#   'squared_geoms__quad_GEOM_R4',
#   -0.06457071287536408),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.06422747990056768),
#  ('not_correlated__Q_G_3_0_1', 'not_correlated__GEOM_R3', 0.06388445892204585),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.06381732817403793),
#  ('not_correlated__GEOM_R3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.06335772197620676),
#  ('not_correlated__Q_NIR_8_0_5',
#   'squared_geoms__quad_GEOM_R1',
#   -0.06283590800357435),
#  ('not_correlated__Q_NIR_8_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.06260733491280801),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_R_4_1_0',
#   0.06195381969920955),
#  ('not_correlated__Q_G_3_0_1', 'log_area__log_AREA', -0.06144687478469719),
#  ('not_correlated__X',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.061172337205526846),
#  ('not_correlated__Q_B_2_0_5',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.06089363267025069),
#  ('not_correlated__Q_R_4_1_0', 'not_correlated__GEOM_R1', 0.06085257974448851),
#  ('log_area__log_AREA', 'pssr__PSSR', -0.06081607995891701),
#  ('not_correlated__GEOM_R2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.06046459179438802),
#  ('not_correlated__GEOM_R3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.06001307917515576),
#  ('not_correlated__Q_NIR_8_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.05817527113435495),
#  ('not_correlated__Q_R_4_1_0',
#   'squared_geoms__quad_GEOM_R1',
#   0.05813105701287039),
#  ('not_correlated__Q_G_3_0_1', 'not_correlated__GEOM_R2', 0.05790962774330149),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.057885879910327884),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   0.057562893986861215),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.057562893986861215),
#  ('not_correlated__Q_NIR_8_0_5',
#   'not_correlated__GEOM_R3',
#   0.05730692005876099),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.05719715124279438),
#  ('not_correlated__Q_B_2_1_0',
#   'not_correlated__GEOM_R3',
#   0.056892459429164384),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   0.05676821605062816),
#  ('not_correlated__Q_B_2_0_1', 'log_area__log_AREA', 0.05618990952791463),
#  ('not_correlated__X', 'squared_geoms__quad_GEOM_R1', -0.055799672181476745),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   0.05564081123335124),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__GEOM_R4',
#   0.055623798457034995),
#  ('not_correlated__Q_R_4_0_1',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.05506784999650013),
#  ('not_correlated__Q_G_3_1_0',
#   'not_correlated__GEOM_R4',
#   0.054743373545921604),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   0.054553039685327175),
#  ('not_correlated__Q_R_4_0_5', 'log_area__log_AREA', 0.054235732377345615),
#  ('not_correlated__X', 'not_correlated__GEOM_R1', -0.05382704860146314),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.05363442675736956),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.05304188512276142),
#  ('not_correlated__Q_G_3_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.05270503112313127),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   0.05234060437216034),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'pssr__PSSR',
#   0.052220860971834974),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   'log_area__log_AREA',
#   0.05181649768628231),
#  ('not_correlated__Q_NIR_8_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   0.05140252180152152),
#  ('not_correlated__GEOM_R4',
#   'squared_geoms__quad_GEOM_R1',
#   0.05105938994636735),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.050847665527778536),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   -0.050661535098150474),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   0.04984207842207406),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__Q_NIR_8_1_0',
#   0.04970236897755157),
#  ('not_correlated__Q_B_2_1_0', 'not_correlated__GEOM_R2', 0.04957014048853561),
#  ('not_correlated__X',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   -0.049434217364526606),
#  ('not_correlated__Q_B_2_1_0',
#   'not_correlated__GEOM_R4',
#   0.049090504325275994),
#  ('not_correlated__Q_NIR_8_1_0',
#   'not_correlated__GEOM_R4',
#   0.04904224915401152),
#  ('not_correlated__Q_NIR_8_0_1',
#   'squared_geoms__quad_GEOM_R1',
#   -0.048839135846674576),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   0.04883164822787256),
#  ('not_correlated__Q_G_3_0_1',
#   'not_correlated__Q_G_3_1_0',
#   0.048484541923794484),
#  ('squared_geoms__quad_GEOM_R1', 'savi__SAVI', -0.04834631767542553),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   0.048083895425954676),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'savi__SAVI',
#   0.04798956428846987),
#  ('not_correlated__Q_G_3_0_5',
#   'not_correlated__Q_NIR_8_0_1',
#   0.04738405624980469),
#  ('not_correlated__GEOM_R3', 'savi__SAVI', 0.04724297847821893),
#  ('not_correlated__GEOM_R1',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.047119275946863964),
#  ('not_correlated__Y', 'not_correlated__Q_NIR_8_0_5', 0.04635707908909302),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   0.046267977983529066),
#  ('not_correlated__Q_G_3_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.045956674168287096),
#  ('not_correlated__Q_G_3_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.045563775493406525),
#  ('not_correlated__Q_R_4_1_0', 'log_area__log_AREA', 0.04551520170676838),
#  ('not_correlated__Q_R_4_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   0.04539218683997786),
#  ('not_correlated__Y', 'squared_geoms__quad_GEOM_R1', -0.04536388319327732),
#  ('not_correlated__Y', 'not_correlated__GEOM_R1', -0.04519936665933052),
#  ('not_correlated__Q_G_3_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.04490849707623343),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'savi__SAVI',
#   0.04485487953354905),
#  ('not_correlated__Q_R_4_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   -0.04415045798994963),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   -0.04366831456585812),
#  ('not_correlated__GEOM_R1',
#   'not_correlated__CONTRUCTIONYEAR',
#   -0.043477140874408786),
#  ('not_correlated__Q_B_2_0_1', 'not_correlated__GEOM_R1', 0.04346991918513405),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.043137130413353715),
#  ('not_correlated__Q_NIR_8_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   0.042702977946565794),
#  ('not_correlated__Q_NIR_8_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   -0.042702977946565725),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.04222773240589409),
#  ('not_correlated__Q_R_4_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.04221317505565302),
#  ('not_correlated__Q_B_2_0_5',
#   'not_correlated__GEOM_R1',
#   0.042012676998744725),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   0.04184795637202812),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   -0.041461672968825344),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   0.04146167296882517),
#  ('not_correlated__Q_G_3_0_5', 'log_area__log_AREA', 0.04139087134926482),
#  ('not_correlated__Q_G_3_0_5',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.04108085254554851),
#  ('not_correlated__Q_B_2_0_5',
#   'squared_geoms__quad_GEOM_R1',
#   0.040793911811904573),
#  ('not_correlated__Q_G_3_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.04077973958710261),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__GEOM_R2',
#   -0.04026906244346999),
#  ('not_correlated__GEOM_R2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.039323537030038165),
#  ('not_correlated__Q_NIR_8_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   0.03913040382991705),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   'log_area__log_AREA',
#   0.03794041909614081),
#  ('not_correlated__Q_NIR_8_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.037919666208580574),
#  ('not_correlated__Q_NIR_8_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   0.03781314432627477),
#  ('log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   'squared_geoms__quad_GEOM_R1',
#   0.03773776572660678),
#  ('not_correlated__GEOM_R3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.037374232671578266),
#  ('not_correlated__Q_B_2_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.03731747805111674),
#  ('not_correlated__GEOM_R1', 'not_correlated__GEOM_R4', 0.0372492619494399),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   0.03705175503361516),
#  ('not_correlated__Q_B_2_0_5',
#   'not_correlated__GEOM_R2',
#   -0.03685408808458252),
#  ('not_correlated__Q_R_4_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   -0.036760076727282695),
#  ('not_correlated__Q_R_4_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   -0.03639023459737074),
#  ('not_correlated__Q_NIR_8_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   0.03593730051469475),
#  ('not_correlated__Q_G_3_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   -0.03584147924022326),
#  ('not_correlated__Q_R_4_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.03487336318779399),
#  ('not_correlated__Q_B_2_0_1',
#   'not_correlated__GEOM_R2',
#   -0.034569809381649684),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'pssr__PSSR',
#   0.03421729297946707),
#  ('not_correlated__Q_B_2_0_1',
#   'squared_geoms__quad_GEOM_R1',
#   0.03395391827726943),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.03369673321930724),
#  ('not_correlated__GEOM_R1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   0.03354881848183936),
#  ('not_correlated__Q_R_4_0_5',
#   'not_correlated__GEOM_R2',
#   -0.03338880457168101),
#  ('not_correlated__Q_G_3_1_0', 'log_area__log_AREA', 0.03333152735050006),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   'pssr__PSSR',
#   0.03319235909179563),
#  ('not_correlated__Q_NIR_8_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   0.032565559228251766),
#  ('not_correlated__Q_NIR_8_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   -0.03256555922825167),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   0.03235621843296476),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   -0.032356218432964524),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'squared_geoms__quad_GEOM_R2',
#   -0.03190110158365878),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'squared_geoms__quad_GEOM_R1',
#   -0.03110982964718625),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.030412967928949992),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   0.03041296792894999),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   0.03041114287358355),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.030411142873583544),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.030323537619362326),
#  ('not_correlated__Q_G_3_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   0.03012259893809074),
#  ('not_correlated__GEOM_R2', 'pssr__PSSR', 0.030062113332289295),
#  ('not_correlated__Q_B_2_1_0',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.029915886737510156),
#  ('not_correlated__GEOM_R3',
#   'not_correlated__CONTRUCTIONYEAR',
#   0.029907845259501287),
#  ('not_correlated__Q_R_4_0_1', 'not_correlated__GEOM_R3', 0.02914636371644107),
#  ('not_correlated__X', 'not_correlated__Q_NIR_8_0_5', 0.028671796334702362),
#  ('not_correlated__X',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.028620467233125994),
#  ('not_correlated__Q_B_2_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.028282829863942035),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.02804698819223283),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__Q_G_3_0_1',
#   0.02799134370849172),
#  ('squared_geoms__quad_GEOM_R1',
#   'squared_geoms__quad_GEOM_R4',
#   0.027392879034881665),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   0.027263863614996164),
#  ('not_correlated__GEOM_R3',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.027218549640137216),
#  ('not_correlated__Q_G_3_0_5',
#   'not_correlated__CONTRUCTIONYEAR',
#   0.02715786881437648),
#  ('not_correlated__Q_B_2_1_0',
#   'not_correlated__Q_NIR_8_0_1',
#   -0.026880032024382047),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'squared_geoms__quad_GEOM_R1',
#   0.026831894474559498),
#  ('not_correlated__Q_B_2_0_1',
#   'not_correlated__GEOM_R3',
#   -0.02650307670867481),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.026194151258870174),
#  ('not_correlated__Y', 'not_correlated__GEOM_R3', -0.02611341604303203),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   'log_area__log_AREA',
#   0.026063676151926504),
#  ('not_correlated__GEOM_R2',
#   'not_correlated__CONTRUCTIONYEAR',
#   0.02602830116294772),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   0.02579987294960012),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.025327057440194475),
#  ('not_correlated__Q_NIR_8_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   0.02528663662777314),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   0.025253269879991446),
#  ('not_correlated__Q_B_2_1_0',
#   'squared_geoms__quad_GEOM_R2',
#   0.02507618505425369),
#  ('not_correlated__Q_R_4_0_1',
#   'not_correlated__CONTRUCTIONYEAR',
#   0.02493975110879951),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   0.02463699535074937),
#  ('not_correlated__GEOM_R1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.02451322569399738),
#  ('not_correlated__GEOM_R1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   0.024513225693997363),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'log_area__log_AREA',
#   -0.024166194836669257),
#  ('not_correlated__X',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.024101779315243745),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   -0.02406130908292123),
#  ('not_correlated__Q_B_2_0_5',
#   'not_correlated__GEOM_R3',
#   -0.023949821864585663),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'squared_geoms__quad_GEOM_R2',
#   -0.023690708433958835),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'log_area__log_AREA',
#   -0.023565616884228775),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   'log_area__log_AREA',
#   0.023565616884228712),
#  ('not_correlated__X',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   -0.023125240864398676),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   'savi__SAVI',
#   0.023044294972668265),
#  ('not_correlated__Q_NIR_8_1_0', 'log_area__log_AREA', 0.02285490303768112),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   -0.02285049158845411),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'squared_geoms__quad_GEOM_R3',
#   -0.022759137574915062),
#  ('not_correlated__GEOM_R2',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.02230772319079938),
#  ('not_correlated__Q_G_3_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.022222139708502744),
#  ('not_correlated__X',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.022157925972213284),
#  ('not_correlated__Q_NIR_8_0_5',
# ...
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.007390356454723756),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'squared_geoms__quad_GEOM_R1',
#   -0.00731950897444715),
#  ('not_correlated__Q_R_4_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   -0.007305268952776877),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'squared_geoms__quad_GEOM_R3',
#   -0.007193394667171361),
#  ('not_correlated__Q_R_4_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   -0.007175387184574814),
#  ('not_correlated__Q_B_2_0_1',
#   'squared_geoms__quad_GEOM_R2',
#   -0.007112986872521492),
#  ('not_correlated__Q_NIR_8_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.007109309004706325),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.007047290911818632),
#  ('not_correlated__Q_G_3_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   -0.007001875052266922),
#  ('not_correlated__Q_NIR_8_1_0',
#   'not_correlated__GEOM_R3',
#   0.006970090069059331),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'squared_geoms__quad_GEOM_R2',
#   0.00676397655909226),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.006673279483971537),
#  ('not_correlated__Q_B_2_0_5',
#   'squared_geoms__quad_GEOM_R2',
#   -0.0065797538470843625),
#  ('not_correlated__X', 'squared_geoms__quad_GEOM_R2', -0.006501122437311181),
#  ('not_correlated__Q_G_3_0_1',
#   'not_correlated__Q_NIR_8_1_0',
#   0.006495633433712575),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'squared_geoms__quad_GEOM_R4',
#   -0.006370403270503065),
#  ('not_correlated__Q_R_4_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   -0.006345800117117557),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   -0.00610002104118451),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   0.00605464534044007),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.006054645340440021),
#  ('not_correlated__Q_B_2_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   0.005949929759379887),
#  ('not_correlated__GEOM_R1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   -0.005910311144508198),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   -0.005747830916654144),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   0.005731017703172981),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   'savi__SAVI',
#   -0.005565830349370503),
#  ('squared_geoms__quad_GEOM_R3', 'savi__SAVI', 0.005562517704968014),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   'pssr__PSSR',
#   0.0054626191907660255),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.005348316594905296),
#  ('not_correlated__Q_R_4_1_0',
#   'not_correlated__GEOM_R3',
#   -0.00534653488950767),
#  ('not_correlated__Q_G_3_1_0',
#   'squared_geoms__quad_GEOM_R2',
#   -0.005311959064891462),
#  ('not_correlated__Q_B_2_0_5',
#   'squared_geoms__quad_GEOM_R4',
#   0.005141528962971004),
#  ('not_correlated__Q_NIR_8_0_1',
#   'not_correlated__GEOM_R4',
#   0.004937117877519704),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'pssr__PSSR',
#   -0.0049078836495893485),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   'pssr__PSSR',
#   0.004907883649589196),
#  ('not_correlated__Q_NIR_8_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   -0.004838624224093129),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   'squared_geoms__quad_GEOM_R1',
#   -0.004795856512448534),
#  ('not_correlated__Q_G_3_0_5',
#   'squared_geoms__quad_GEOM_R4',
#   0.004738704723992123),
#  ('not_correlated__Q_NIR_8_0_1',
#   'squared_geoms__quad_GEOM_R3',
#   0.0046671397030469035),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.004637340800427917),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   -0.004637340800427037),
#  ('not_correlated__Q_NIR_8_0_5',
#   'squared_geoms__quad_GEOM_R3',
#   0.0045992617940190635),
#  ('not_correlated__Y', 'squared_geoms__quad_GEOM_R3', -0.004571095057758816),
#  ('not_correlated__Q_B_2_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   0.004550902240797973),
#  ('not_correlated__X', 'squared_geoms__quad_GEOM_R4', -0.004470742796002453),
#  ('not_correlated__Y', 'squared_geoms__quad_GEOM_R2', -0.004353249755439015),
#  ('not_correlated__Q_R_4_0_1',
#   'squared_geoms__quad_GEOM_R4',
#   0.004342796903375852),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   -0.004298368158916221),
#  ('not_correlated__Q_B_2_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   0.004249889717916218),
#  ('not_correlated__Q_B_2_1_0',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.004249889717915936),
#  ('not_correlated__Y',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.004061428838625889),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   'squared_geoms__quad_GEOM_R2',
#   -0.003932312172582252),
#  ('not_correlated__Q_NIR_8_0_1',
#   'squared_geoms__quad_GEOM_R4',
#   0.003901098606745509),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'squared_geoms__quad_GEOM_R2',
#   -0.0038209467770574444),
#  ('log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   'squared_geoms__quad_GEOM_R4',
#   -0.003783355548383212),
#  ('not_correlated__Q_R_4_0_5',
#   'squared_geoms__quad_GEOM_R3',
#   -0.0037719591907964217),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   -0.0035610210084415007),
#  ('not_correlated__GEOM_R1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   -0.0033469525281560075),
#  ('not_correlated__Q_R_4_0_1',
#   'squared_geoms__quad_GEOM_R3',
#   0.0033366018356911246),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.0033311693923525044),
#  ('not_correlated__Q_R_4_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   -0.003214920942864033),
#  ('squared_geoms__quad_GEOM_R2', 'pssr__PSSR', 0.0032035136689081986),
#  ('not_correlated__Q_R_4_0_1',
#   'squared_geoms__quad_GEOM_R2',
#   0.0031714570157864576),
#  ('not_correlated__GEOM_R4',
#   'not_correlated__CONTRUCTIONYEAR',
#   -0.003117967651937098),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'squared_geoms__quad_GEOM_R4',
#   0.003079444871458965),
#  ('not_correlated__Q_R_4_0_5',
#   'squared_geoms__quad_GEOM_R4',
#   0.0030301791993449885),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   0.0030128766606824365),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.0030128766606823966),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   0.0030098837763195816),
#  ('not_correlated__Q_G_3_0_1',
#   'squared_geoms__quad_GEOM_R4',
#   0.002968900374599674),
#  ('not_correlated__GEOM_R4',
#   'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   0.0028895441245392994),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   'squared_geoms__quad_GEOM_R3',
#   -0.0028854908069853294),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   0.0028590446036952785),
#  ('not_correlated__Q_B_2_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   -0.002859044603694835),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   'squared_geoms__quad_GEOM_R2',
#   -0.0028559322089315295),
#  ('squared_geoms__quad_GEOM_R4', 'pssr__PSSR', -0.002832171197324306),
#  ('squared_geoms__quad_GEOM_R4', 'savi__SAVI', -0.002811841714472893),
#  ('not_correlated__X', 'not_correlated__GEOM_R3', -0.0027767188829642343),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   'squared_geoms__quad_GEOM_R2',
#   -0.0027337764120703902),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'squared_geoms__quad_GEOM_R2',
#   0.0027337764120703816),
#  ('not_correlated__Q_R_4_1_0',
#   'squared_geoms__quad_GEOM_R3',
#   -0.002687376411272089),
#  ('not_correlated__GEOM_R1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   -0.002584512836393435),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#   'squared_geoms__quad_GEOM_R4',
#   -0.0024225121960887715),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   0.002416346771288904),
#  ('not_correlated__Q_B_2_0_1',
#   'squared_geoms__quad_GEOM_R4',
#   0.002346304786213429),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   'squared_geoms__quad_GEOM_R1',
#   -0.002321104336883421),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   -0.0022613854056710756),
#  ('not_correlated__X', 'not_correlated__GEOM_R4', 0.0022423395806492556),
#  ('log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#   'squared_geoms__quad_GEOM_R2',
#   -0.0022357246075902144),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'squared_geoms__quad_GEOM_R2',
#   0.0022269893774502195),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   'squared_geoms__quad_GEOM_R3',
#   -0.002217633122133398),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'squared_geoms__quad_GEOM_R3',
#   0.002217633122133387),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.0021278708886254645),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   -0.002055865399290799),
#  ('not_correlated__Q_G_3_0_5',
#   'squared_geoms__quad_GEOM_R2',
#   -0.0020445304119627522),
#  ('not_correlated__Q_B_2_1_0',
#   'not_correlated__Q_NIR_8_0_5',
#   0.001963869750655018),
#  ('not_correlated__Q_NIR_8_1_0',
#   'squared_geoms__quad_GEOM_R2',
#   -0.0019598818979709885),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.0019292205713277724),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'squared_geoms__quad_GEOM_R3',
#   0.001877683599310702),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#   0.001851079974959019),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   0.0018479415893641776),
#  ('not_correlated__CONTRUCTIONYEAR',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.0018479415893640756),
#  ('not_correlated__GEOM_R1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   0.0018296869645456054),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   -0.001829304894587368),
#  ('not_correlated__Q_B_2_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   0.0018293048945873525),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   'squared_geoms__quad_GEOM_R4',
#   0.00169099368765225),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   'squared_geoms__quad_GEOM_R3',
#   -0.0016411074548364699),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   -0.0016074863679222532),
#  ('not_correlated__Q_NIR_8_1_0',
#   'squared_geoms__quad_GEOM_R3',
#   -0.0015908635043721364),
#  ('not_correlated__Q_B_2_0_5',
#   'squared_geoms__quad_GEOM_R3',
#   -0.0015514070233513203),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   0.0014851153514746894),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.001485115351474614),
#  ('not_correlated__Q_G_3_0_5',
#   'not_correlated__GEOM_R3',
#   0.0014627608773523826),
#  ('not_correlated__X', 'not_correlated__Y', 0.0014422271000245573),
#  ('squared_geoms__quad_GEOM_R3', 'pssr__PSSR', -0.001416168751836748),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   0.0013458501183248965),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'squared_geoms__quad_GEOM_R4',
#   -0.0013360669116507884),
#  ('not_correlated__Q_NIR_8_0_5',
#   'squared_geoms__quad_GEOM_R4',
#   -0.0013027164109171822),
#  ('not_correlated__Q_G_3_0_1',
#   'not_correlated__GEOM_R1',
#   0.001265748382803573),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#   'squared_geoms__quad_GEOM_R4',
#   0.0012642978921120487),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#   'squared_geoms__quad_GEOM_R4',
#   -0.0011390133418488478),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   'savi__SAVI',
#   -0.0011237751824522326),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#   'squared_geoms__quad_GEOM_R4',
#   -0.0010448645580472486),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#   'squared_geoms__quad_GEOM_R3',
#   -0.0010008508802664988),
#  ('not_correlated__Q_NIR_8_0_1',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.0009664819230705898),
#  ('not_correlated__Q_G_3_1_0',
#   'squared_geoms__quad_GEOM_R3',
#   0.0009110760639912312),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   0.0008291750097426417),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.0008291750097426165),
#  ('not_correlated__Q_B_2_0_1',
#   'squared_geoms__quad_GEOM_R3',
#   -0.000822408486148921),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   'squared_geoms__quad_GEOM_R4',
#   -0.0008124093583708879),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.000669380584613808),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   0.000669380584613805),
#  ('not_correlated__Q_NIR_8_0_5',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#   0.0005485862757944989),
#  ('not_correlated__Q_G_3_0_5',
#   'squared_geoms__quad_GEOM_R3',
#   0.0005429540473355003),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#   0.0005326628244657337),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   'squared_geoms__quad_GEOM_R4',
#   0.0004965758401432868),
#  ('not_correlated__GEOM_R4',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   -0.00045570464271724805),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   0.00043547595537542406),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.0004354759553754088),
#  ('not_correlated__X', 'squared_geoms__quad_GEOM_R3', 0.00032783486743066185),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#   'squared_geoms__quad_GEOM_R4',
#   -0.0003158504057611412),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   0.00030786458116064),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#   'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   -0.0003078645811606296),
#  ('not_correlated__X', 'not_correlated__Q_B_2_1_0', 0.0001895798030159759),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#   'squared_geoms__quad_GEOM_R4',
#   -0.00012099758902257343),
#  ('cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#   'squared_geoms__quad_GEOM_R4',
#   0.00012099758902257218),
#  ('not_correlated__Y', 'squared_geoms__quad_GEOM_R4', -3.9639782517433505e-05)]

# %%
corr_matrix = transformed_data.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.9)]

# %%
len(to_drop)
# Out:
# 9

# %%
to_drop
# Out:
# ['not_correlated__Q_G_3_0_1',
#  'not_correlated__Q_G_3_0_5',
#  'not_correlated__Q_G_3_1_0',
#  'not_correlated__Q_B_2_0_5',
#  'not_correlated__Q_NIR_8_1_0',
#  'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_Na',
#  'log_antiquity__log_CONTRUCTIONYEAR_antiquity',
#  'squared_geoms__quad_GEOM_R1',
#  'savi__SAVI']

# %%
dropped_highly = transformed_data.copy()
dropped_highly.drop(columns=to_drop, inplace=True)
dropped_highly.columns
# Out:
# Index(['not_correlated__X', 'not_correlated__Y', 'not_correlated__Q_R_4_0_1',
#        'not_correlated__Q_R_4_0_5', 'not_correlated__Q_R_4_1_0',
#        'not_correlated__Q_B_2_0_1', 'not_correlated__Q_B_2_1_0',
#        'not_correlated__Q_NIR_8_0_1', 'not_correlated__Q_NIR_8_0_5',
#        'not_correlated__GEOM_R1', 'not_correlated__GEOM_R2',
#        'not_correlated__GEOM_R3', 'not_correlated__GEOM_R4',
#        'not_correlated__CONTRUCTIONYEAR',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_9',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_8',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_7',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_6',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_5',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_4',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_3',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_2',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_1',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_C',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_B',
#        'cadastral_ordinal_encoder_onehot__CADASTRALQUALITYID_A',
#        'log_area__log_AREA', 'squared_geoms__quad_GEOM_R2',
#        'squared_geoms__quad_GEOM_R3', 'squared_geoms__quad_GEOM_R4',
#        'pssr__PSSR'],
#       dtype='object')

# %%
dropped_highly.shape
# Out:
# (82584, 31)

# %%
imbt = ImbalanceTransformer(min_samples=min_samples, max_samples=max_samples)

# %%
X,y = imbt.fit_resample(dropped_highly, df[TARGET_FEATURE])

# %%
X.shape
# Out:
# (19597, 31)

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()
gb.fit(X, y)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
from sklearn.metrics import *
def calculate_metrics(y_true, y_pred):
    return {
        'accuracy': accuracy_score(y_true, y_pred),
        'balanced_accuracy': balanced_accuracy_score(y_true, y_pred),
        'precision_macro': precision_score(y_true, y_pred, average='macro'),
        'precision_weighted': precision_score(y_true, y_pred, average='weighted'),
        'recall_macro': recall_score(y_true, y_pred, average='macro'),
        'recall_weighted': recall_score(y_true, y_pred, average='weighted'),
        'f1_macro': f1_score(y_true, y_pred, average='macro'),
        'f1_weighted': f1_score(y_true, y_pred, average='weighted'),
    }

# %%
calculate_metrics(y, gb.predict(X))
# Out:
# {'accuracy': 0.6925549829055467,
#  'balanced_accuracy': 0.5594842662071581,
#  'precision_macro': 0.695506908938056,
#  'precision_weighted': 0.6855671051906608,
#  'recall_macro': 0.5594842662071581,
#  'recall_weighted': 0.6925549829055467,
#  'f1_macro': 0.590695713517712,
#  'f1_weighted': 0.6627500799499345}

# %%
t_df_test = pipe.transform(df_test)
t_df_test = pd.DataFrame(t_df_test, columns=pipe.named_steps['features'].get_feature_names())
calculate_metrics(df_test[TARGET_FEATURE], gb.predict(t_df_test.drop(columns=to_drop)))
# Out:
# {'accuracy': 0.8579385837450354,
#  'balanced_accuracy': 0.4714332731665511,
#  'precision_macro': 0.4519462943927353,
#  'precision_weighted': 0.8746145673410394,
#  'recall_macro': 0.4714332731665511,
#  'recall_weighted': 0.8579385837450354,
#  'f1_macro': 0.44710731468950404,
#  'f1_weighted': 0.8636437006494757}

# %%
model.metrics
# Out:
# {'train': {'accuracy': 0.8645258161387194,
#   'custom_accuracy': 0.6843253705115877,
#   'balanced_accuracy': 0.5587315929133986,
#   'precision_macro': 0.516373940354464,
#   'precision_weighted': 0.883704681315883,
#   'recall_macro': 0.5587315929133986,
#   'recall_weighted': 0.8645258161387194,
#   'f1_macro': 0.5174336119273506,
#   'f1_weighted': 0.8706946954115227}}

# %%
model.evaluate(df_test, df_test[TARGET_FEATURE])

# %%
model.metrics
# Out:
# {'train': {'accuracy': 0.8645258161387194,
#   'custom_accuracy': 0.6843253705115877,
#   'balanced_accuracy': 0.5587315929133986,
#   'precision_macro': 0.516373940354464,
#   'precision_weighted': 0.883704681315883,
#   'recall_macro': 0.5587315929133986,
#   'recall_weighted': 0.8645258161387194,
#   'f1_macro': 0.5174336119273506,
#   'f1_weighted': 0.8706946954115227},
#  'test': {'accuracy': 0.8575510994865834,
#   'custom_accuracy': 0.6526893452099854,
#   'balanced_accuracy': 0.4927809653044917,
#   'precision_macro': 0.46682769092666104,
#   'precision_weighted': 0.8760241555378591,
#   'recall_macro': 0.4927809653044917,
#   'recall_weighted': 0.8575510994865834,
#   'f1_macro': 0.4637404246862448,
#   'f1_weighted': 0.8638738592777445}}

# %%
model.get_feature_importances().sort_values('importance', ascending=False)
# Out:
#                                               feature  importance
# 32                                 log_area__log_AREA    0.247576
# 11                        not_correlated__Q_NIR_8_0_1    0.100917
# 15                            not_correlated__GEOM_R2    0.072901
# 16                            not_correlated__GEOM_R3    0.065027
# 1                                   not_correlated__Y    0.057786
# 0                                   not_correlated__X    0.056298
# 10                          not_correlated__Q_B_2_1_0    0.046219
# 9                           not_correlated__Q_B_2_0_5    0.037388
# 12                        not_correlated__Q_NIR_8_0_5    0.032232
# 35                        squared_geoms__quad_GEOM_R2    0.031341
# 34                        squared_geoms__quad_GEOM_R1    0.029747
# 14                            not_correlated__GEOM_R1    0.022642
# 5                           not_correlated__Q_G_3_0_1    0.020074
# 6                           not_correlated__Q_G_3_0_5    0.017824
# 2                           not_correlated__Q_R_4_0_1    0.016104
# 33       log_antiquity__log_CONTRUCTIONYEAR_antiquity    0.015378
# 24  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.014106
# 36                        squared_geoms__quad_GEOM_R3    0.012925
# 18                    not_correlated__CONTRUCTIONYEAR    0.012297
# 8                           not_correlated__Q_B_2_0_1    0.012285
# 7                           not_correlated__Q_G_3_1_0    0.010123
# 17                            not_correlated__GEOM_R4    0.009243
# 13                        not_correlated__Q_NIR_8_1_0    0.008427
# 21  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.008117
# 37                        squared_geoms__quad_GEOM_R4    0.007361
# 4                           not_correlated__Q_R_4_1_0    0.007202
# 38                                         pssr__PSSR    0.006038
# 23  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.004562
# 39                                         savi__SAVI    0.004247
# 3                           not_correlated__Q_R_4_0_5    0.003221
# 22  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.002667
# 28  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.002553
# 25  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.001360
# 20  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.001357
# 27  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.000872
# 26  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.000681
# 29  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.000534
# 31  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.000339
# 19  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.000028
# 30  cadastral_ordinal_encoder_onehot__CADASTRALQUA...    0.000000
