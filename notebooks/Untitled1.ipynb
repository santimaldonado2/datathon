# %%
import sys
import os
sys.path.insert(0, os.path.abspath('/home/maldo/projects/virtualenvs/datathon/lib/python3.7/site-packages'))
sys.path.insert(0, os.path.abspath('/home/maldo/projects/datathon'))
from imblearn.under_sampling import *
from imblearn.over_sampling import *
from imblearn.combine import *
from src.models.model import SoilClassifier
from src.constants import *
from src.features.features import *
from src.experiments.experiments import run_experiment
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import pandas as pd
import seaborn as sns
import math

# %%
df = pd.read_csv(os.path.join('../data/processed', 'train_data_imbalanced.csv'))
df_train2 = pd.read_csv(os.path.join('../data/processed', 'train_data_imbalanced.csv'))
df_test2 = pd.read_csv(os.path.join('../data/processed', 'test_data_imbalanced.csv'))

# %%
df_train2[['X', 'Y', 'GEOM_R1', 'GEOM_R2', 'GEOM_R3',
       'GEOM_R4']]
# Out:
#                 X          Y   GEOM_R1   GEOM_R2   GEOM_R3   GEOM_R4
# 0      2221401266  165595371  0.481048  0.030713  0.030581  0.995719
# 1      2201312158  165915444  0.375703  0.010439  0.013359  1.279789
# 2      2212177085  165578234  0.818341  0.046189  0.038300  0.829184
# 3      2276314547  165581387  0.751811  0.081699  0.093809  1.148218
# 4      2193223196  165581746  0.013223  0.029656  0.029950  1.009913
# ...           ...        ...       ...       ...       ...       ...
# 82579  2207340352  165572743  0.393495  0.028869  0.045517  1.576650
# 82580  2203385899  165645215  0.801473  0.078064  0.049554  0.634787
# 82581  2208968936  165240520  0.968089  0.096805  0.065705  0.678735
# 82582  2194968098  165361548  0.994582  0.226244  0.106067  0.468816
# 82583  2217907829  165707521  0.918704  0.079055  0.191571  2.423276
#
# [82584 rows x 6 columns]

# %%
classifier2 = SoilClassifier()
classifier2.load('../src/experiments/results/imbalanced_1_gradient_boosting_500_9000_scaled.pkl')
classifier2.evaluate(df_test2,df_test2[TARGET_FEATURE])
classifier2.metrics
# Out:
# {'test': {'accuracy': 0.8538215634989829,
#   'custom_accuracy': 0.6491475190932925,
#   'balanced_accuracy': 0.48565467612776014,
#   'precision_macro': 0.4749710635254955,
#   'precision_weighted': 0.8752377128367731,
#   'recall_macro': 0.48565467612776014,
#   'recall_weighted': 0.8538215634989829,
#   'f1_macro': 0.46292777816764563,
#   'f1_weighted': 0.861209403477862}}

# %%
df_test2[TARGET_FEATURE].value_counts()
# Out:
# RESIDENTIAL    17956
# INDUSTRIAL       965
# PUBLIC           579
# RETAIL           420
# OFFICE           377
# OTHER            281
# AGRICULTURE       68
# Name: CLASE, dtype: int64

# %%
train_predictions = classifier2.predict(df_train2)

# %%
train_predictions
# Out:
# array(['RESIDENTIAL', 'PUBLIC', 'RESIDENTIAL', ..., 'RESIDENTIAL',
#        'RESIDENTIAL', 'RESIDENTIAL'], dtype=object)

# %%
def get_weight(class_name):
    if class_name == 'RESIDENTIAL':
        return 0.12
    if class_name == 'AGRICULTURE':
        return 2
    else:
        return 1

weights = df_test2[TARGET_FEATURE].apply(get_weight)
((df_test2[TARGET_FEATURE]==predictions)*weights).sum()/weights.sum()
# Out:
# 0.6491475190932925

# %%
train_weights = df_train2[TARGET_FEATURE].apply(get_weight)
((df_train2[TARGET_FEATURE]==train_predictions)*train_weights).sum()/train_weights.sum()
# Out:
# 0.6868389642253239

# %%
classifier2.calculate_metrics(df_train2[TARGET_FEATURE], train_predictions)
# Out:
# {'accuracy': 0.862116148406471,
#  'balanced_accuracy': 0.5656203705691063,
#  'precision_macro': 0.5247612048030478,
#  'precision_weighted': 0.885354619219458,
#  'recall_macro': 0.5656203705691063,
#  'recall_weighted': 0.862116148406471,
#  'f1_macro': 0.5246699902101313,
#  'f1_weighted': 0.869950100572724}

# %%
weights = df_test2[TARGET_FEATURE].apply(get_weight)

# %%
predictions = classifier2.predict(df_test2)

# %%
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy_score(df_test2[TARGET_FEATURE], predictions, sample_weight=weights)
# Out:
# 0.48565467612776014

# %%
# Out:
# 0.8538215634989829

# %%
transformer.fit(df)
# Out:
# ScalerTransformer(keys=['X', 'Y', 'Q_R_4_0_0', 'Q_R_4_0_1', 'Q_R_4_0_2',
#                         'Q_R_4_0_3', 'Q_R_4_0_4', 'Q_R_4_0_5', 'Q_R_4_0_6',
#                         'Q_R_4_0_7', 'Q_R_4_0_8', 'Q_R_4_0_9', 'Q_R_4_1_0',
#                         'Q_G_3_0_0', 'Q_G_3_0_1', 'Q_G_3_0_2', 'Q_G_3_0_3',
#                         'Q_G_3_0_4', 'Q_G_3_0_5', 'Q_G_3_0_6', 'Q_G_3_0_7',
#                         'Q_G_3_0_8', 'Q_G_3_0_9', 'Q_G_3_1_0', 'Q_B_2_0_0',
#                         'Q_B_2_0_1', 'Q_B_2_0_2', 'Q_B_2_0_3', 'Q_B_2_0_4',
#                         'Q_B_2_0_5', ...])

# %%
df
# Out:
#                      ID           X          Y     Q_R_4_0_0   Q_R_4_0_1  \
# 0      1C636E0FD3E41438  2221401266  165595371  0.000000e+00  297.000085
# 1      5F0483FCC14402B9  2201312158  165915444  0.000000e+00  443.001300
# 2      50783FDA2B52CD54  2212177085  165578234  1.308316e-10  405.999329
# 3      7AB4777F33D76F17  2276314547  165581387  2.690274e-11  536.503235
# 4      3B191BDECAE2C539  2193223196  165581746  2.670131e-11  322.999893
